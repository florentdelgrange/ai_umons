# %%
from scipy.io import loadmat
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

def show(x):
    imgplot = plt.imshow(x)
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show()

# %%
length = 43390
X_train = np.memmap('../Dataset/training_images', dtype='uint8', mode='r', shape=(length, 299, 299, 3))
gender_train = np.memmap('../Dataset/training_genders', dtype='uint8', mode='r', shape=(length))
age_train = np.memmap('../Dataset/training_ages', dtype='uint8', mode='r', shape=(length))

# %%
f = plt.figure()
f.set_dpi(150)
plt.hist(age_train, bins=50, range=(0,110))
plt.grid(ls='--')
plt.tight_layout()
plt.show()
